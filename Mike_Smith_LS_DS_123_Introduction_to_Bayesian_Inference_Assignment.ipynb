# %% [markdown]
# <a href="https://colab.research.google.com/github/gomlfx/DS-Unit-1-Sprint-2-Statistics/blob/master/Mike_Smith_LS_DS_123_Introduction_to_Bayesian_Inference_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lambda School Data Science Module 123
#
# ## Introduction to Bayesian Inference

# %%
#replicate the code to practice
vanilla = 30+20
choco = 10+20
cookies  = vanilla+choco
print(cookies)
p_V = vanilla/cookies
print(p_V)
# Out:
# 80
# 0.625

# %%
#p(vanilla|Bowl 1) conditional probability, Given that I pick from bowl 1, what is the probability of randomly drawing a vanilla cookie?
p_B1 = 1 #prior
p_VB1 = 30/40
print(p_VB1)
# Out:
# 0.75

# %%
#now suppose you choose one of the bowls at random and without looking select a cookie at random. The cookie is vanilla, what is the probability that it came from Bowl 1?
#p(Bowl 1 | vanilla) conditional probability
p_B1 = .5
p_VB1 = .75
p_V = 50/80
p_B1V = (p_B1*p_VB1)/p_V
print(p_B1V)
# Out:
# 0.6

# %%
#let's recreate the game with code.
import random

def lets_make_a_deal(initial, secondary):
  doors=['a','b','c']
  second_choices = ['KEEP', 'SWITCH']
  car = random.choice(doors)
  if initial == car and secondary =='KEEP':
    result = 1
  elif initial != car and secondary == 'SWITCH':
    result = 1
  else: 
    result = 0
  print(f'Car was behind door {car}. You initially picked {initial} and the you decided to {secondary}. Points = {result}')
  return result

# %%
#try out my def 
lets_make_a_deal('c', 'SWITCH')
# Out:
# Car was behind door c. You initially picked c and the you decided to SWITCH. Points = 0
# 0

# %%
#PLAY 1000 times, which strategy is better?
wins = 0
doors=['a','b','c']
for x in range(0,10000):
  points = lets_make_a_deal(random.choice(doors), 'SWITCH')
  wins = wins + points
print('total points if switch:', wins)
# Out:
# Car was behind door c. You initially picked a and the you decided to SWITCH. Points = 1
# Car was behind door a. You initially picked a and the you decided to SWITCH. Points = 0
# Car was behind door b. You initially picked c and the you decided to SWITCH. Points = 1
# Car was behind door a. You initially picked c and the you decided to SWITCH. Points = 1
# Car was behind door c. You initially picked a and the you decided to SWITCH. Points = 1
# Car was behind door c. You initially picked b and the you decided to SWITCH. Points = 1
# Car was behind door a. You initially picked b and the you decided to SWITCH. Points = 1
# Car was behind door b. You initially picked c and the you decided to SWITCH. Points = 1
# Car was behind door c. You initially picked c and the you decided to SWITCH. Points = 0
# Car was behind door c. You initially picked b and the you decided to SWITCH. Points = 1
# Car was behind door b. You initially picked a and the you decided to SWITCH. Points = 1
# ...

# %%
prior = .33
marginal = .5
conditional = (.5*.33)+(0*.33)+(1*.33)

# %%
#P(car is A | choice is A) = (marginal * prior) / conditional
posterior = (prior * conditional)/marginal
print(posterior)
# Out:
# 0.3267

# %%
#P(car is C | choice is  A) = 1-P(car is A | choice is A)
round(1-posterior,3)
# Out:
# 0.673

# %%
#if you pick a door then switch after seeing another door opened, the probability of choosing the right door increases from 1/3 to 2/3.
#It's based on this information it's always in our best interest to swtich.
#that concludes monty hall problem.

# %%
#this section is prototype for the assignment #We have a person take a drug test.
#prior belief
P_user = 1/200
#complement of the prior belief
P_non_user = 1 - P_user
#true positive rate
P_pos_given_user = 1
#false positive rate
P_pos_given_nonuser = 0.01

# %%
#1st iteration of Bayes Theorem #1st test.
numerator = P_pos_given_user * P_user
denom = (P_pos_given_user * P_user) + (P_pos_given_nonuser * P_non_user)
posterior1 = numerator / denom
print(posterior1)
# Out:
# 0.33444816053511706

# %%
#we hve the same person take the drug test again, and they test positive again. #2nd test
#what's the likelihodd they're a drug user?
#the posterior probability from the 1st test becomes the prior for the 2nd test. (The Almighty ITERATION!)
P_user = posterior1
P_nonuser = 1 - P_user
#run Bayes theorem
numerator = P_pos_given_user * P_user
denom = (P_pos_given_user * P_user) + (P_pos_given_nonuser * P_non_user)
posterior2 = numerator / denom
print(posterior2)
# Out:
# 0.9711090210686957

# %%
#3rd test #but this iteration is not looped
P_user = posterior2
P_nonuser = 1 - P_user
#run Bayes theorem
numerator = P_pos_given_user * P_user
denom = (P_pos_given_user * P_user) + (P_pos_given_nonuser * P_non_user)
posterior3 = numerator / denom
print(posterior3)
# Out:
# 0.9898578986724355

# %%
#4rd test #but this iteration is not looped
P_user = posterior3
P_nonuser = 1 - P_user
#run Bayes theorem
numerator = P_pos_given_user * P_user
denom = (P_pos_given_user * P_user) + (P_pos_given_nonuser * P_non_user)
posterior4 = numerator / denom
print(posterior4)
# Out:
# 0.9900480882245362

# %%
#4th test #as you can see because the iteration is not automatic, it can get tiring. We have to make it automatic.

# %%
#turn all of that into a function
def prob_drug_use(prior, fpr, tpr, num_tests):
  posterior = prior
  for test in range(0, num_tests):
#prior belief
P_user = 1/200
#complement of the prior belief
P_non_user = 1 - P_user
#true positive rate
P_pos_given_user = 1
#false positive rate
P_pos_given_nonuser = 0.01
# Out:
#   File "<ipython-input-18-1bf551dd50bc>", line 5
#     P_user = 1/200
#                   ^
# IndentationError: expected an indented block

# %% [markdown]
# ## Assignment - Code it up!
#
# We used pure math to apply Bayes Theorem to drug tests. Now write Python code to reproduce the results! This is purposefully open ended - you'll have to think about how you should represent probabilities and events. You can and should look things up.
#
# Specific goals/targets:
#
# ### 1) Write a function
#
# `def prob_drunk_given_positive(prob_drunk_prior, false_positive_rate):`
#
# You should only truly need these two values in order to apply Bayes Theorem. In this example, imagine that individuals are taking a breathalyzer test with an 8% false positive rate, a 100% true positive rate, and that our prior belief about drunk driving in the population is 1/1000.
#  - What is the probability that a person is drunk after one positive breathalyzer test?
#  - What is the probability that a person is drunk after two positive breathalyzer tests?
#  - How many positive breathalyzer tests are needed in order to have a probability that's greater than 95% that a person is drunk beyond the legal limit?
#
# ### 2) Explore `scipy.stats.bayes_mvs`
# Read its documentation, and experiment with it on data you've tested in other ways earlier this week.
#  - Create a visualization comparing the results of a Bayesian approach to a traditional/frequentist approach. (with a large sample size they should look close to identical, however, take this opportunity to practice visualizing condfidence intervals in general. The following are some potential ways that you could visualize confidence intervals on your graph:
#   - [Matplotlib Error Bars](https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.errorbar.html)
#   - [Seaborn barplot with error bars](https://seaborn.pydata.org/generated/seaborn.barplot.html)
#   - [Vertical ines to show bounds of confidence interval](https://www.simplypsychology.org/confidence-interval.jpg)
#   - [Confidence Intervals on Box Plots](https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.axes.Axes.boxplot.html)
#
# ### 3) In your own words, summarize the difference between Bayesian and Frequentist statistics
#
# If you're unsure where to start, check out [this blog post of Bayes theorem with Python](https://dataconomy.com/2015/02/introduction-to-bayes-theorem-with-python/).

# %%
#copied model from lecture, but changed for assignment

P_user = 1/1000
#complement of the prior belief
P_non_user = 1 - P_user
#true positive rate
P_pos_given_user = 1
#false positive rate
P_pos_given_nonuser = 0.08

# %%
#1st iteration of Bayes Theorem
numerator = P_pos_given_user * P_user
denom = (P_pos_given_user * P_user) + (P_pos_given_nonuser * P_non_user)
posterior = numerator / denom
print(posterior)

# %%
We get the point! Save time! Loop it!

# %%
#(1)
# TODO - code! 
 def prob_drunk(prior, fpr, tpr, num_tests): 
   posterior = prior
   for test in range(0, num_tests):
     #prior belief
     P_user = posterior
     #complement of the prior belief
     P_non_user = 1-P_user
     #true positive rate
     P_pos_given_user = 1
     #false positive rate
     P_pos_given_nonuser = .08
     #theorem
     numerator = P_pos_given_user * P_user
     denom = (P_pos_given_user * P_user) + (P_pos_given_nonuser * P_non_user)
     posterior = numerator / denom
   return posterior

# %%
#What is the probability that a person is drunk after one positive breathalyzer test?
prob_drunk(1/1000, .08, 1, 1) #prob_drunk

# %%
#What is the probability that a person is drunk after two positive breathalyzer tests?
prob_drunk(1/1000, .08, 1, 2) #prob_drunk

# %%
#Q: How many positive breathalyzer tests are needed in order to have a probability that's greater than 95% that a person is drunk beyond the legal limit?
#A: It takes 4 tests to in order to have a probability that's greater than 95% that a person is drunk beyond the legal limit.

# %%
prob_drunk(1/1000, .08, 1, 4) #prob_drunk

# %%
#////////////////end of (1) drunk driving test//////////////////

# %%
# #(2) Explore scipy.stats.bayes_mvs
# Read its documentation, and experiment with it on data you've tested in other ways earlier this week.
# Create a visualization comparing the results of a Bayesian approach to a traditional/frequentist approach.
# (with a large sample size they should look close to identical, however, take this opportunity to practice 
# visualizing condfidence intervals in general. The following are some potential ways that you could visualize confidence intervals on your graph:
from scipy.stats import bayes_mvs
import pandas as pd
#!wget = 
c_h = pd.read_csv("sample_data/california_housing_test.csv")
c_h.head()
bayes_mvs(c_h)



#scipy.stats.bayes_mvs
# Out:
# (Mean(statistic=23424.134866125925, minmax=(22676.214007869545, 24172.055724382306)),
#  Variance(statistic=5582394713.691164, minmax=(5503366727.845909, 5661422699.536419)),
#  Std_dev(statistic=74715.4248712484, minmax=(74186.56496058445, 75244.28478191234)))

# %%
#///////////////////////end of (2)//////////////////////////

# %%
#(3) In your own words, summarize the difference between Bayesian and Frequentist statistics

# %% [markdown]
# It's good you asked, because I spent quite some time on that very question. There's a lot to say about it. Like Frequentist as a rule observe things as they happen, and reacting to it. A Bayesian will form an opinion and try to see if their opinion is correct as the input comes in. The Bayesian approach in my understanding is more biased than the a frequentist who will generally form no bias or anything to disprove and will simply allow the observation to form the definition. Bayesian also seems to be more theoretical approach to probability theory, where frequentism appears more applied. Why? Because the questions one could pose about a situation before executing a test is the Bayesian method. This is sympomatic of philosophy which does not require empirical observation of their theories. This suspicion is further confirmed by the fact that Bayesian theory was popular before the 20th century. And frequentist is more popular after 20th century. Bayesian is similar to an AGI (artificial general intelligence) consciousness contemplating on what action would be ideal to take on the physical world, without ever actually had taken any physical action. Frequentist on the other side would be an AGI taking action on its physical environment and forming ideas about what is the best next action due to its experience. On the other hand as it's name suggest, frequentists define probability based on the frequency which something happened, or 'long-term frequency'. Also they have a fundamental belief in predicting using patterns. But Bayesian probability is based in degrees of logical support (then belief).
# As a long term practitioner of probabilities for my own business needs I would then agree that frequentist probability is a simpler, lower level, and Bayesian is a higher level which could easily outmaneuver frequentist probability. Due to it's core belief in using pure logic to determine empirical situations, I justify Bayesian theory is worthy to study more for practical application.

# %% [markdown]
# ## Resources

# %% [markdown]
# - [Worked example of Bayes rule calculation](https://en.wikipedia.org/wiki/Bayes'_theorem#Examples) (helpful as it fully breaks out the denominator)
# - [Source code for mvsdist in scipy](https://github.com/scipy/scipy/blob/90534919e139d2a81c24bf08341734ff41a3db12/scipy/stats/morestats.py#L139)

# %% [markdown]
# ## Stretch Goals:
#
# - Go back and study the content from Modules 1 & 2 to make sure that you're really comfortable with them.
# - Apply a Bayesian technique to a problem you previously worked (in an assignment or project work) on from a frequentist (standard) perspective
# - Check out [PyMC3](https://docs.pymc.io/) (note this goes beyond hypothesis tests into modeling) - read the guides and work through some examples
# - Take PyMC3 further - see if you can build something with it!

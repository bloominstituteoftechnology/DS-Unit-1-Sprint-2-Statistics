# %% [markdown]
# <a href="https://colab.research.google.com/github/gomlfx/DS-Unit-1-Sprint-2-Statistics/blob/master/Mike_Smith_module4_Initial_Project_Survey.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Assignment!
# Fill out the template twice, for two different ideas.
#
# I don't have two different ideas. I have one project, I have had it for years, and the primary reason for joining Lambdaschool.
#
# Then compare and contrast and select one as the idea you're leaning towards working on for your project week.
#
# I know what I want to solve. So, it's hard to think of two to contrast. I simply have one that I know I want to work on. Perhaps there are various ways to work on it. But I have a primary dataset I want to solve.
#
# Ideas for data storytelling - Idea 1
# You
# What do you care about?
#
# Forein Exchange Rates
#
# What do you know about?
#
# Foreign Exchange Rates
#
# What decisions do you face?
#
# What are tomorrows values, the 0-24 GMT shape, the closing price, the 0-24 GMT min, max value.
#
# Seven templates
# Training Kit (https://learn.lambdaschool.com/ds/module/recedjanlbpqxic2r) explains the seven templates from Priceonomics.
#
# Can you apply the templates to your topics?
#
# Yes, at this time think "5. Data you have that is valuable to businesses:" is the most relevent. The other topics I could relate and order by my interest and public interest.
#
# Geographic Variation
#
# Trend related to the news
#
# Who does that?
#
# Answering a question people care about
#
# Valuable to businesses
#
# What's the most popular?
#
# Cost/Money rankings
#
# Misconceptions
# What misconceptions do people have about your topic?
#
# What external sources actually influence currency price, such as new release time, type.
#
# Examples
# What data storytelling example inspires you?
#
# I like data modeling, predicting and modelling a probable future.
# That's why I like machine learning. With my data, we are always looking for
# modelling of any range of time from 1 hour, day, week, month, year, decade, century. So, this is why I think this application for machine learning is very interesting.
#
# Could you do a new hypothesis, for the same question?
#
# Yes, I very much like the Bayesian method for probability. Before I started data scientist study ant lambda, I was more a frequentist problem solver to my project. But now I have shifted to bayesian.
#
# Could you do a new question, for the same topic?
#
# yes, because bayesian requires us to form new theories to process better probability models.
#
# Could you do a new topic, with the same "style"?
#
# “Find a subject you care about and which you in your heart feel others should care about. It is this genuine caring, and not your games with language, which will be the most compelling and seductive element in your style.” --KurtVonnegut
#
# I like this quote, because it definitely tells me that I should use lambda data science course on my current project. I have been doing it for years, totally misguided, as I can see. It's something I like a lot, and can share style with other people.
#
# Data
# Where could you search for data about your topic?
#
# The data is everywhere, API's, raw data sources, there's more than enough data, from private sources, and gov sources. International, anywhere you need to get it. The biggest problems I would work on is what type of features (data) to choose to ammend to what I use now, where to get new data (data sources).
#
# Ideas for data storytelling - Idea 2
# You
# What do you care about?
# health
# What do you know about?
# not much, as a us citizen we don't get much of it, if one is not rich.
# What decisions do you face?
# where can I get the same type full coverage health care that citizens of other developed countries get, such as Canada, Japan, Taiwan, Australia.
#
# Seven templates
# Training Kit (https://learn.lambdaschool.com/ds/module/recedjanlbpqxic2r) explains the seven templates from Priceonomics.
#
# Can you apply the templates to your topics?
#
# Geographic Variation
#
# Trend related to the news
#
# oh yes, sure, trends related to the quality of health of people in various developed countries to their health care coverages.
#
# Who does that?
#
# I don't know much about this topic. I can already tell, I don't care much about it, because it's a hopeless situation. If one doesn't have money in US, you have no hope of getting health care.
#
# Answering a question people care about
#
# Valuable to businesses
#
# What's the most popular?
#
# Cost/Money rankings
#
# Misconceptions
# What misconceptions do people have about your topic?
#
# Examples
# What data storytelling example inspires you?
#
# Could you do a new hypothesis, for the same question?
#
# Could you do a new question, for the same topic?
#
# Could you do a new topic, with the same "style"?
#
#
# Data
# Where could you search for data about your topic?

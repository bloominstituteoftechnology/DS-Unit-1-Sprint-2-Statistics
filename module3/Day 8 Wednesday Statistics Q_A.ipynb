# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ryanleeallred/datasets/master/adult.csv', na_values=' ?')

df.head()
# Out:
#    age          workclass  fnlwgt  ... hours-per-week         country  salary
# 0   39          State-gov   77516  ...             40   United-States   <=50K
# 1   50   Self-emp-not-inc   83311  ...             13   United-States   <=50K
# 2   38            Private  215646  ...             40   United-States   <=50K
# 3   53            Private  234721  ...             40   United-States   <=50K
# 4   28            Private  338409  ...             40            Cuba   <=50K
#
# [5 rows x 15 columns]

# %% [markdown]
# # Chi^2 Test
#
# ## What does the chi^2 test, test for?
#
# 1) Test for Independence/dependence
#
# What does Independence Mean? It means that there's no relationship between two variables (columns) of my dataframe.
#
# The opposite of independence is dependence. If two things are dependent, they are likely to be correlated. (relationship, association)
#
# ### Null Hypothesis: Independent (No Relationship)
#
# ### Alternative Hypothesis: Dependent (Relationship)
#
# ### Confidence Level: 95%
#
# **A chi^2 test can only be done on categorical variables.**

# %% [markdown]
# ## I want to do a chi^2 test for gender/sex and hours worked per week.
#
# Our intuition tells us that we would expect these to variables to be related.

# %%
df['sex'].describe()
# Out:
# count     32561
# unique        2
# top        Male
# freq      21790
# Name: sex, dtype: object

# %%
df['sex'].value_counts()
# Out:
#  Male      21790
#  Female    10771
# Name: sex, dtype: int64

# %%
df['hours-per-week'].describe()
# Out:
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000
# Name: hours-per-week, dtype: float64

# %%
df['hours-per-week'].value_counts()
# Out:
# 40    15217
# 50     2819
# 45     1824
# 60     1475
# 35     1297
#       ...
# 92        1
# 94        1
# 87        1
# 74        1
# 82        1
# Name: hours-per-week, Length: 94, dtype: int64

# %%
df.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# country           object
# salary            object
# dtype: object

# %%
df['hours-per-week'].hist(bins=100);

# %%
pd.crosstab(df['hours-per-week'], df['sex'])
# Out:
# sex              Female   Male
# hours-per-week
# 1                    10     10
# 2                    14     18
# 3                    14     25
# 4                    32     22
# 5                    32     28
# ...                 ...    ...
# 95                    0      2
# 96                    0      5
# 97                    0      2
# 98                    0     11
# 99                   19     66
#
# [94 rows x 2 columns]

# %% [markdown]
# ## Bin the hours-per-week column so that it has fewer categories

# %%
# margins=True will include the row and column totals in the table
pd.crosstab(df['40_hours'], df['sex'], margins=True)
# Out:
# sex           Female   Male    All
# 40_hours
# < 40 hours      4107   3656   7763
# >= 40 hours     6664  18134  24798
# All            10771  21790  32561

# %%
cut_points = [0,39,1000]
bin_names = ['< 40 hours', '>= 40 hours']

df['40_hours'] = pd.cut(df['hours-per-week'], cut_points, labels=bin_names)

df.head()
# Out:
#    age          workclass  fnlwgt  ...  salary  hours_per_week_bins     40_hours
# 0   39          State-gov   77516  ...   <=50K                40-49  >= 40 hours
# 1   50   Self-emp-not-inc   83311  ...   <=50K                10-19   < 40 hours
# 2   38            Private  215646  ...   <=50K                40-49  >= 40 hours
# 3   53            Private  234721  ...   <=50K                40-49  >= 40 hours
# 4   28            Private  338409  ...   <=50K                40-49  >= 40 hours
#
# [5 rows x 17 columns]

# %%
# The values that I want to separate the bins
cut_points = [0,9,19,29,39,49,1000]
bin_names = ['0-9', '10-19', '20-29', '30-39', '40-49', '50+']

df['hours_per_week_bins'] = pd.cut(df['hours-per-week'], cut_points, labels=bin_names)

df.head()
# Out:
#    age          workclass  fnlwgt  ...  salary  hours_per_week_bins     40_hours
# 0   39          State-gov   77516  ...   <=50K                40-49  >= 40 hours
# 1   50   Self-emp-not-inc   83311  ...   <=50K                10-19   < 40 hours
# 2   38            Private  215646  ...   <=50K                40-49  >= 40 hours
# 3   53            Private  234721  ...   <=50K                40-49  >= 40 hours
# 4   28            Private  338409  ...   <=50K                40-49  >= 40 hours
#
# [5 rows x 17 columns]

# %%
df['hours_per_week_bins'].describe()
# Out:
# count     32561
# unique        6
# top       40-49
# freq      18336
# Name: hours_per_week_bins, dtype: object

# %%
contingency_table = pd.crosstab(df['sex'], df['hours_per_week_bins'])

contingency_table
# Out:
# hours_per_week_bins  0-9  10-19  20-29  30-39  40-49   50+
# sex
#  Female              235    671   1287   1914   5636  1028
#  Male                223    575   1105   1753  12700  5434

# %%
from scipy import stats

chi2, p_value, dof, expected_value_table = stats.chi2_contingency(contingency_table)

print("Chi^2 Statistic:", chi2)
print("P value:", p_value)
print("Degrees of Freedom", dof)
print('Expected Value Table: \n', expected_value_table)
# Out:
# Chi^2 Statistic: 2287.190943926107
# P value: 0.0
# Degrees of Freedom 5
# Expected Value Table:
#  [[  151.50388502   412.16995793   791.26046497  1213.02346365
#    6065.44811277  2137.59411566]
#  [  306.49611498   833.83004207  1600.73953503  2453.97653635
#   12270.55188723  4324.40588434]]

# %% [markdown]
# We compared our p-value to .05, since it is less than .05 we reject the null hypothesis.
#
# 1 - Confidence_Level = .05
#
# 1 - .95 = .05

# %%
# ?stats.chi2_contingency

# %% [markdown]
# ### Conclusion:
#
# Based on a Chi^2 statistic of 2287 and a p-value of 0, I **reject** the null hypothesis that sex and hours-worked-per-week-bins are independent and suggest the alternative, that they are associated.

# %% [markdown]
# # Calculate our Chi^2 statistic using NumPy

# %%
contingency_table
# Out:
# hours_per_week_bins  0-9  10-19  20-29  30-39  40-49   50+
# sex
#  Female              235    671   1287   1914   5636  1028
#  Male                223    575   1105   1753  12700  5434

# %%
contingency_with_margins = pd.crosstab(df['sex'], df['hours_per_week_bins'], margins=True)

contingency_with_margins
# Out:
# hours_per_week_bins  0-9  10-19  20-29  30-39  40-49   50+    All
# sex
#  Female              235    671   1287   1914   5636  1028  10771
#  Male                223    575   1105   1753  12700  5434  21790
# All                  458   1246   2392   3667  18336  6462  32561

# %% [markdown]
# ### Calculate our Expected Value Table
#
# Expected Value Table: What I would expect the values in the contingency table to be **if the null hypothesis (independence) were true**.
#
# For any given cell in our contingency table. The expected value for that cell is calculated by:
#
# \begin{align}
# expected_{i,j} = \frac{(\text{row total})(\text{column total})}{\text{(sample size)}}
# \end{align}

# %%
# What proportion of people would we expect to work 0-9 hours per week?
458 / 32561
# Out:
# 0.01406590706673628

# %%
# What proportion of people would we expect to be female?
10771 / 32561
# Out:
# 0.33079450876815825

# %%
(458 / 32561)*(10771 / 32561)
# Out:
# 0.004652924818519593

# %%
(458 / 32561)*(10771 / 32561) * 32561
# Out:
# 151.50388501581648

# %%
# The expepcted value for cell: (row 1, column 1)
(458)*(10771)/32561
# Out:
# 151.50388501581648

# %% [markdown]
# ## Make the Expected Value Table
#
# All that the next 3 cells are doing is pulling the values out of my table, into lists that I can loop over in order to do the calculation of the expected values.

# %%
# Grab the crosstab cells that correspond to the females
femalecount = contingency_table.iloc[0][0:6].values
femalecount
# Out:
# array([ 235,  671, 1287, 1914, 5636, 1028])

# %%
# Grab the crosstab cells that correspond to the females
malecount = contingency_table.iloc[1][0:6].values
malecount
# Out:
# array([  223,   575,  1105,  1753, 12700,  5434])

# %%
# Calculate row and column totals to use in the expected value calculations
row_sums = contingency_with_margins.iloc[0:2, 6].values
col_sums = contingency_with_margins.iloc[2, 0:6].values

total = contingency_with_margins.loc['All','All']

print(row_sums)
print(col_sums)
print(total)
# Out:
# [10771 21790]
# [  458  1246  2392  3667 18336  6462]
# 32561

# %%
# Now we have everything that we need to calculate our table of expected values
expected = []
for i in range(len(row_sums)):
  expected_row = []
  for column in col_sums:
    expected_val = column*row_sums[i]/total
    expected_row.append(expected_val)
  expected.append(expected_row)
  
expected = np.array(expected)

expected
# Out:
# array([[  151.50388502,   412.16995793,   791.26046497,  1213.02346365,
#          6065.44811277,  2137.59411566],
#        [  306.49611498,   833.83004207,  1600.73953503,  2453.97653635,
#         12270.55188723,  4324.40588434]])

# %% [markdown]
# ## Calculating the chi^2 Statistic
#
# The chi^2 statistic is a number that represents how different my observed values contingency table (comes from my data/sample) is from the expected value table.
#
# If they're very similar then it's likely that the null hypothesis is true.
#
# If they're very different, then it's likely that the null hypothesis is false.
#
# When we want to know how different two numbers are, we often calculate what is called a "squared deviation" just like in the numerator of the chi^2 static calculation
#
# \begin{align}
# \chi^2 = \sum \frac{(observed_{i}-expected_{i})^2}{(expected_{i})}
# \end{align}

# %%
observed = contingency_table
observed
# Out:
# hours_per_week_bins  0-9  10-19  20-29  30-39  40-49   50+
# sex
#  Female              235    671   1287   1914   5636  1028
#  Male                223    575   1105   1753  12700  5434

# %%
expected
# Out:
# array([[  151.50388502,   412.16995793,   791.26046497,  1213.02346365,
#          6065.44811277,  2137.59411566],
#        [  306.49611498,   833.83004207,  1600.73953503,  2453.97653635,
#         12270.55188723,  4324.40588434]])

# %%
# Row 1 Column 5 of both of my tables
# I will do this calculation with all of the cells of the table
# And then add them all up
(5636 - 6065.448)**2 / 6065.448
# Out:
# 30.405929570907254

# %%
chi_squared = (((observed - expected)**2)/expected).sum().sum()

chi_squared
# Out:
# 2287.1909439261076

# %% [markdown]
# 1) Calculate a Contingency Table for my observed data (crosstab)
#
# 2) Calculate the Expected Value Table for my data: (row_total)(column_total)/(sample_size)
#
# 3) I figure out how different those two tables are by looking at the squared deviation between the two divided by the expected value.
#
# 4) Sum up all of the squared deviation values to get one single value that serves as my chi^2 statistic

# %% [markdown]
# ## How does the chi^2 statistic result in a p-value?
#
# <https://homepage.divms.uiowa.edu/~mbognar/applets/chisq.html>
#
# 1) How many Degrees of Freedom?
#
# (# rows - 1)*(# columns - 1)
#
# (2 - 1)(6 - 1) =
#
# 5 degrees of freedom

# %% [markdown]
# ### Conclusion:
#
# Based on a Chi^2 statistic of 2287 and a p-value of 0, I **reject** the null hypothesis that sex and hours-worked-per-week-bins are independent and suggest the alternative, that they are associated.

# %%
# Summing up the first row of my expected value table
np.sum([151.50388502,   412.16995793,   791.26046497,  1213.02346365,
         6065.44811277,  2137.59411566])

# Confirm that row totals, column totals, and sample size of the expected value 
# table are the same as those in the observed values table
# Out:
# 10771.0

# %%
df.describe(exclude='number')
# Out:
#        workclass education  ... hours_per_week_bins     40_hours
# count      30725     32561  ...               32561        32561
# unique         8        16  ...                   6            2
# top      Private   HS-grad  ...               40-49  >= 40 hours
# freq       22696     10501  ...               18336        24798
#
# [4 rows x 11 columns]

# %%
df['education'].value_counts()
# Out:
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5355
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           333
#  1st-4th           168
#  Preschool          51
# Name: education, dtype: int64

# %%
df['sex'].value_counts()
# Out:
#  Male      21790
#  Female    10771
# Name: sex, dtype: int64

# %%
contingency = pd.crosstab(df['sex'], df['education'])
contingency
# Out:
# education   10th   11th   12th  ...   Preschool   Prof-school   Some-college
# sex                             ...
#  Female      295    432    144  ...          16            92           2806
#  Male        638    743    289  ...          35           484           4485
#
# [2 rows x 16 columns]

# %%
chi2, p_value, dof, expected_value_table = stats.chi2_contingency(contingency)

print("Chi^2 Statistic:", chi2)
print("P value:", p_value)
print("Degrees of Freedom", dof)
print('Expected Value Table: \n', expected_value_table)
# Out:
# Chi^2 Statistic: 297.71500372503687
# P value: 1.667778440920507e-54
# Degrees of Freedom 15
# Expected Value Table:
#  [[ 308.63127668  388.6835478   143.2340223    55.57347747  110.15457142
#    213.69325266  170.02837751  352.95774086  457.15801112 1771.40459445
#    136.61813212 3473.67313657  569.95893861   16.87051995  190.53763705
#   2411.82276343]
#  [ 624.36872332  786.3164522   289.7659777   112.42652253  222.84542858
#    432.30674734  343.97162249  714.04225914  924.84198888 3583.59540555
#    276.38186788 7027.32686343 1153.04106139   34.12948005  385.46236295
#   4879.17723657]]

# %% [markdown]
# Based on a chi^2 statistic of 297 and a p-value of 0 I reject the null hypothesis that years of education obtained and sex of census respondents are independent, and suggest the alternative, that they are associated.

# %% [markdown]
# # T Tests and the T-statistic with the adult dataset

# %%
df.describe()
# Out:
#                 age        fnlwgt  ...  capital-loss  hours-per-week
# count  32561.000000  3.256100e+04  ...  32561.000000    32561.000000
# mean      38.581647  1.897784e+05  ...     87.303830       40.437456
# std       13.640433  1.055500e+05  ...    402.960219       12.347429
# min       17.000000  1.228500e+04  ...      0.000000        1.000000
# 25%       28.000000  1.178270e+05  ...      0.000000       40.000000
# 50%       37.000000  1.783560e+05  ...      0.000000       40.000000
# 75%       48.000000  2.370510e+05  ...      0.000000       45.000000
# max       90.000000  1.484705e+06  ...   4356.000000       99.000000
#
# [8 rows x 6 columns]

# %%
df['education-num'].describe()
# Out:
# count    32561.000000
# mean        10.080679
# std          2.572720
# min          1.000000
# 25%          9.000000
# 50%         10.000000
# 75%         12.000000
# max         16.000000
# Name: education-num, dtype: float64

# %%
df['education-num'].mean()
# Out:
# 10.0806793403151

# %% [markdown]
# I want to test the hypothesis that in 1984 census respondents on average had completed 12 years of education (finished high school)
#
# Null Hypothesis: sample_mean == 12 (your average census respondant has completed high school)
#
# Alternative Hypothesis sample_mean != 12
#
# Confidence Level: 95%
#
# ![](https://benmis.files.wordpress.com/2013/10/t_test_formula_one_way.gif)

# %%
# Sample mean
x_bar = df['education-num'].mean()
# null hypothesis value (can be a population parameter if I want)
mu = 12
# SAMPLE standard devation
s = df['education-num'].std()
# Sample Size
n = len(df['education-num'])

t = ((x_bar - mu) / (s / np.sqrt(n)))

print("T Statistic:", t)
# Out:
# T Statistic: -134.61821465310183

# %% [markdown]
# What does the sign on the t-statistic tell us?
#
# The only way I can get a negative number in the above equation is if `mu` is greater than `x_bar`
#
# So for my one-sample t-test this means that the sample mean is less than 12.
#
# What does the t-statistic number itself represent?
#
# In our case, we have a big sample size which means that we're estimating the mean with a lot of precision (we have pretty good / specific idea of where it is). Our sample mean isn't jumping all over the place as we take different samples of this same size, it's pretty much nailed down due to our large sample size. **our denominator is small**
#
# Our sample mean is not super far away from the null hypothesis value, but it's not extremely close either. **average sized numerator**
#
# ## What does the t-statistic represent?
#
# It's a number that represents a comparison between how far apart our means are, compared to how random the sampling process is with our given sample size.
#
# We're just trying to quantify how different our means are compared to the randomness inherent in the sampling process.
#
# ## How do I translate a t-statistic into a p-value?
#
# How many degrees of freedom do I have?
#
# n-1 degrees of freedom = 32560 dof (That's a whole lot!)
#
# <https://homepage.divms.uiowa.edu/~mbognar/applets/t.html>
#
# p-value: very very close to 0

# %% [markdown]
# ## Conclusion:
#
# Based on a t-statistic of -131, and a p-value of 0, I *reject* the null hypothesis that the population mean is equal to 12, and suggest the alternative, that it is different than 12.

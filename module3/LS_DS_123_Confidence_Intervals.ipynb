# %% [markdown]
# <a href="https://colab.research.google.com/github/John-G-Thomas/DS-Unit-1-Sprint-2-Statistics/blob/master/module3/LS_DS_123_Confidence_Intervals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lambda School Data Science Module 123
# ## Confidence Intervals
#
# Objectives:
#
# - Student can explain the concepts of statistical estimate, precision, and standard error in regards to inferential statistics
# - Student can explain the implications of the central limit theorem in inferential statistics
# - Student can explain the purpose of confidence intervals and identify applications for their use
# - Studnet can demonstrate how to build a confidence interval around a sample estimate
# - Student can report margin of error and visualize graphically a confidence interval to communicate the precision of sample estimates to a non-technical audience

# %% [markdown]
# ## Estimates, Precision, and Standard Error
#
# - Estimate: Generate a sample statistic -from a sample in hopes that it is representative of some larger population parameter.
#
# - Point Estimate: When we report a single specific number as our estimate.
#
# - Sample Error: How far off our sample point estimate could be due to the randomness of the sample process. Point estimates do not sufficiently communicate potential sampl error.

# %% [markdown]
# ### "Precision" vs "Accuracy"
#
# ![Precision vs Accuracy](https://www.researchgate.net/profile/Anni_Helena_Ruotsala/publication/304674901/figure/fig6/AS:668649476067338@1536429866393/Precision-versus-accuracy-The-bullseye-represents-the-true-value-eg-the-true.ppm)

# %% [markdown]
# $\beta$ - A parameter of a linear regression model (slope or intercept)
#
# $\hat{\beta}$ - The value for the slope or intercept that is estimated from our sample.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
coinflips = np.random.binomial(n=1, p=.5, size=12)

coinflips.mean()
# Out:
# 0.5

# %% [markdown]
# ## Central Limit Theorem
#
# What really is Sample Error?
#
# We need to get an even better understanding of "Standard Error"

# %%
sample_means = []
for x in range(0,3000):
  coinflips = np.random.binomial(n=1, p=.5, size=12)
  one_sample = coinflips
  sample_means.append(coinflips.mean())

print(len(sample_means))
print(sample_means)
# Out:
# 3000
# [0.4166666666666667, 0.4166666666666667, 0.5, 0.5, 0.4166666666666667, 0.5, 0.4166666666666667, 0.5, 0.5833333333333334, 0.5833333333333334, 0.4166666666666667, 0.5, 0.5833333333333334, 0.8333333333333334, 0.5833333333333334, 0.16666666666666666, 0.5, 0.4166666666666667, 0.5833333333333334, 0.4166666666666667, 0.4166666666666667, 0.5833333333333334, 0.5, 0.4166666666666667, 0.4166666666666667, 0.4166666666666667, 0.5, 0.4166666666666667, 0.5, 0.3333333333333333, 0.5833333333333334, 0.5, 0.4166666666666667, 0.5, 0.5833333333333334, 0.3333333333333333, 0.5, 0.8333333333333334, 0.5833333333333334, 0.3333333333333333, 0.5, 0.5, 0.3333333333333333, 0.3333333333333333, 0.5, 0.3333333333333333, 0.3333333333333333, 0.4166666666666667, 0.8333333333333334, 0.4166666666666667, 0.5, 0.4166666666666667, 0.5833333333333334, 0.4166666666666667, 0.3333333333333333, 0.5833333333333334, 0.6666666666666666, 0.8333333333333334, 0.5833333333333334, 0.6666666666666666, 0.25, 0.25, 0.5, 0.5833333333333334, 0.3333333333333333, 0.5833333333333334, 0.4166666666666667, 0.5, 0.3333333333333333, 0.3333333333333333, 0.5833333333333334, 0.5833333333333334, 0.25, 0.6666666666666666, 0.5833333333333334, 0.5833333333333334, 0.3333333333333333, 0.25, 0.5833333333333334, 0.5833333333333334, 0.5, 0.5, 0.3333333333333333, 0.5833333333333334, 0.75, 0.5833333333333334, 0.5, 0.4166666666666667, 0.5833333333333334, 0.6666666666666666, 0.25, 0.4166666666666667, 0.5, 0.5, 0.5833333333333334, 0.5833333333333334, 0.4166666666666667, 0.6666666666666666, 0.75, 0.5833333333333334, 0.6666666666666666, 0.5833333333333334, 0.25, 0.3333333333333333, 0.4166666666666667, 0.5833333333333334, 0.25, 0.75, 0.5833333333333334, 0.4166666666666667, 0.5, 0.6666666666666666, 0.5, 0.4166666666666667, 0.5, 0.5, 0.5833333333333334, 0.3333333333333333, 0.3333333333333333, 0.5, 0.4166666666666667, 0.6666666666666666, 0.5833333333333334, 0.75, 0.5, 0.6666666666666666, 0.5, 0.25, 0.6666666666666666, 0.3333333333333333, 0.75, 0.5833333333333334, 0.5833333333333334, 0.3333333333333333, 0.75, 0.5, 0.3333333333333333, 0.3333333333333333, 0.5, 0.5, 0.3333333333333333, 0.5, 0.5833333333333334, 0.4166666666666667, 0.3333333333333333, 0.6666666666666666, 0.5833333333333334, 0.5, 0.75, 0.3333333333333333, 0.5833333333333334, 0.4166666666666667, 0.5833333333333334, 0.6666666666666666, 0.3333333333333333, 0.4166666666666667, 0.3333333333333333, 0.5, 0.5, 0.4166666666666667, 0.6666666666666666, 0.4166666666666667, 0.5, 0.75, 0.6666666666666666, 0.5833333333333334, 0.16666666666666666, 0.3333333333333333, 0.5833333333333334, 0.5, 0.4166666666666667, 0.4166666666666667, 0.25, 0.5, 0.4166666666666667, 0.25, 0.6666666666666666, 0.5833333333333334, 0.5, 0.3333333333333333, 0.5833333333333334, 0.5833333333333334, 0.5833333333333334, 0.4166666666666667, 0.75, 0.5, 0.5, 0.5833333333333334, 0.5833333333333334, 0.5833333333333334, 0.4166666666666667, 0.3333333333333333, 0.25, 0.5833333333333334, 0.6666666666666666, 0.6666666666666666, 0.3333333333333333, 0.8333333333333334, 0.5, 0.5, 0.5833333333333334, 0.5, 0.4166666666666667, 0.5, 0.5, 0.4166666666666667, 0.5, 0.5, 0.6666666666666666, 0.4166666666666667, 0.5, 0.5833333333333334, 0.5833333333333334, 0.4166666666666667, 0.3333333333333333, 0.5833333333333334, 0.3333333333333333, 0.75, 0.4166666666666667, 0.4166666666666667, 0.5, 0.4166666666666667, 0.5, 0.5833333333333334, 0.75, 0.5833333333333334, 0.5, 0.8333333333333334, 0.3333333333333333, 0.3333333333333333, 0.6666666666666666, 0.4166666666666667, 0.3333333333333333, 0.4166666666666667, 0.5833333333333334, 0.4166666666666667, 0.5, 0.5, 0.5833333333333334, 0.5, 0.3333333333333333, 0.5, 0.4166666666666667, 0.4166666666666667, 0.6666666666666666, 0.3333333333333333, 0.5833333333333334, 0.5, 0.4166666666666667, 0.5, 0.5, 0.25, 0.5833333333333334, 0.16666666666666666, 0.5833333333333334, 0.6666666666666666, 0.16666666666666666, 0.5, 0.25, 0.3333333333333333, 0.75, 0.5833333333333334, 0.5, 0.5, 0.5, 0.75, 0.5, 0.4166666 ...

# %%
df = pd.DataFrame({'single_sample': one_sample})

df.head()
# Out:
#    single_sample
# 0              1
# 1              0
# 2              1
# 3              1
# 4              0

# %%
df['single_sample'].hist();

# %%
df['single_sample'].plot.density();

# %%
plt.hist(sample_means, bins=23)
plt.show()

# %%
sample_means = []
for x in range(0,3000):
  coinflips = np.random.binomial(n=1, p=.5, size=50)
  one_sample = coinflips
  sample_means.append(coinflips.mean())

print(len(sample_means))
print(sample_means)
# Out:
# 3000
# [0.46, 0.54, 0.5, 0.56, 0.52, 0.52, 0.42, 0.44, 0.52, 0.56, 0.54, 0.62, 0.42, 0.48, 0.52, 0.56, 0.38, 0.42, 0.56, 0.52, 0.36, 0.48, 0.62, 0.6, 0.46, 0.54, 0.46, 0.34, 0.44, 0.64, 0.48, 0.6, 0.62, 0.44, 0.36, 0.6, 0.38, 0.62, 0.44, 0.5, 0.46, 0.36, 0.34, 0.46, 0.48, 0.38, 0.42, 0.5, 0.4, 0.44, 0.5, 0.44, 0.56, 0.6, 0.4, 0.54, 0.54, 0.48, 0.52, 0.48, 0.54, 0.42, 0.44, 0.56, 0.42, 0.5, 0.5, 0.4, 0.42, 0.48, 0.54, 0.44, 0.5, 0.54, 0.54, 0.4, 0.52, 0.5, 0.36, 0.4, 0.62, 0.5, 0.44, 0.54, 0.5, 0.46, 0.46, 0.44, 0.48, 0.54, 0.48, 0.46, 0.44, 0.46, 0.58, 0.5, 0.48, 0.54, 0.44, 0.46, 0.54, 0.54, 0.5, 0.54, 0.38, 0.46, 0.5, 0.36, 0.6, 0.48, 0.56, 0.62, 0.4, 0.52, 0.5, 0.62, 0.5, 0.48, 0.5, 0.42, 0.48, 0.5, 0.56, 0.56, 0.56, 0.42, 0.56, 0.58, 0.44, 0.44, 0.5, 0.52, 0.48, 0.44, 0.44, 0.52, 0.46, 0.52, 0.58, 0.7, 0.5, 0.52, 0.38, 0.44, 0.6, 0.64, 0.38, 0.58, 0.58, 0.36, 0.36, 0.52, 0.58, 0.42, 0.5, 0.44, 0.56, 0.56, 0.5, 0.38, 0.56, 0.52, 0.5, 0.58, 0.5, 0.56, 0.52, 0.46, 0.6, 0.56, 0.56, 0.42, 0.46, 0.56, 0.38, 0.54, 0.56, 0.48, 0.54, 0.5, 0.5, 0.62, 0.44, 0.5, 0.44, 0.46, 0.56, 0.36, 0.36, 0.6, 0.56, 0.48, 0.58, 0.68, 0.54, 0.52, 0.56, 0.56, 0.68, 0.52, 0.56, 0.66, 0.52, 0.36, 0.5, 0.58, 0.52, 0.6, 0.42, 0.52, 0.48, 0.4, 0.52, 0.38, 0.46, 0.54, 0.54, 0.52, 0.46, 0.46, 0.52, 0.42, 0.5, 0.48, 0.38, 0.64, 0.56, 0.46, 0.64, 0.68, 0.4, 0.52, 0.44, 0.42, 0.42, 0.52, 0.5, 0.54, 0.5, 0.44, 0.46, 0.46, 0.58, 0.44, 0.4, 0.46, 0.56, 0.58, 0.5, 0.4, 0.48, 0.36, 0.52, 0.5, 0.54, 0.56, 0.44, 0.44, 0.52, 0.38, 0.52, 0.56, 0.54, 0.5, 0.54, 0.54, 0.48, 0.56, 0.54, 0.5, 0.44, 0.5, 0.4, 0.68, 0.52, 0.42, 0.46, 0.46, 0.52, 0.4, 0.36, 0.48, 0.56, 0.58, 0.46, 0.46, 0.52, 0.46, 0.42, 0.58, 0.38, 0.58, 0.48, 0.5, 0.46, 0.54, 0.5, 0.58, 0.42, 0.64, 0.52, 0.58, 0.66, 0.62, 0.64, 0.44, 0.42, 0.5, 0.42, 0.68, 0.62, 0.48, 0.48, 0.5, 0.4, 0.42, 0.4, 0.52, 0.48, 0.48, 0.5, 0.5, 0.54, 0.5, 0.52, 0.54, 0.46, 0.62, 0.44, 0.56, 0.54, 0.5, 0.54, 0.46, 0.56, 0.5, 0.5, 0.42, 0.5, 0.58, 0.42, 0.54, 0.62, 0.44, 0.42, 0.46, 0.54, 0.52, 0.48, 0.56, 0.42, 0.48, 0.44, 0.52, 0.36, 0.56, 0.6, 0.48, 0.5, 0.46, 0.64, 0.54, 0.38, 0.58, 0.52, 0.52, 0.5, 0.38, 0.56, 0.42, 0.54, 0.44, 0.54, 0.46, 0.56, 0.54, 0.6, 0.54, 0.52, 0.46, 0.5, 0.48, 0.6, 0.44, 0.36, 0.36, 0.5, 0.52, 0.56, 0.58, 0.54, 0.5, 0.48, 0.5, 0.42, 0.6, 0.5, 0.54, 0.4, 0.54, 0.68, 0.5, 0.52, 0.5, 0.56, 0.46, 0.52, 0.4, 0.5, 0.48, 0.56, 0.4, 0.46, 0.58, 0.54, 0.48, 0.44, 0.52, 0.52, 0.5, 0.54, 0.54, 0.5, 0.38, 0.46, 0.38, 0.58, 0.44, 0.5, 0.46, 0.46, 0.5, 0.5, 0.5, 0.46, 0.42, 0.64, 0.6, 0.46, 0.42, 0.46, 0.5, 0.46, 0.52, 0.66, 0.46, 0.52, 0.6, 0.52, 0.6, 0.48, 0.52, 0.56, 0.52, 0.5, 0.52, 0.56, 0.38, 0.62, 0.42, 0.54, 0.4, 0.48, 0.6, 0.62, 0.52, 0.58, 0.6, 0.56, 0.42, 0.5, 0.66, 0.52, 0.4, 0.5, 0.6, 0.58, 0.5, 0.52, 0.56, 0.44, 0.48, 0.44, 0.62, 0.52, 0.54, 0.52, 0.48, 0.56, 0.52, 0.48, 0.42, 0.56, 0.48, 0.48, 0.56, 0.54, 0.36, 0.5, 0.3, 0.42, 0.58, 0.48, 0.48, 0.52, 0.42, 0.46, 0.56, 0.54, 0.48, 0.48, 0.54, 0.52, 0.52, 0.58, 0.6, 0.48, 0.46, 0.66, 0.6, 0.6, 0.46, 0.54, 0.4, 0.44, 0.5, 0.58, 0.44, 0.68, 0.4, 0.48, 0.4, 0.48, 0.42, 0.54, 0.54, 0.46, 0.46, 0.62, 0.54, 0.52, 0.5, 0.42, 0.6, 0.46, 0.56, 0.48, 0.42, 0.58, 0.44, 0.44, 0.52, 0.48, 0.56, 0.4, 0.58, 0.44, 0.7, 0.46, 0.46, 0.5, 0.44, 0.44, 0.5, 0.54, 0.48, 0.58, 0.48, 0.42, 0.52, 0.52, 0.5, 0.48, 0.62, 0.6, 0.58, 0.36, 0.5, 0.48, 0.54, 0.48, 0.44, 0.48, 0.48, 0.48, 0.48, 0.54, 0.5, 0.58, 0.4, 0.44, 0.54, 0.48, 0.48, 0.48, 0.44, 0.54, 0.44, 0.42, 0.5, 0.58, 0.52, 0.5, 0.46, 0.52, 0.46, 0.42, 0.46, 0.6, 0.46, 0.3, 0.5, 0.46, 0.4, 0.42, 0.52, 0.42, 0.38, 0.56, 0.44, 0.52, 0.48, 0.52, 0.5, 0.48, 0.62, 0.5, 0.56, 0.56, 0.56, 0.36, 0.56, 0.44, 0.6, 0.6, 0.5, 0.48, 0.54, 0.46, 0.54, 0.62, 0.52, 0.52, 0.44, 0.56, 0.56, 0.44, 0.58, 0.4, 0.56, 0.48, 0.46, 0.46, 0.54, 0.46, 0.4, 0.44, 0.38, 0.46, 0.62, 0.48, 0.54, 0.4, 0.46, 0.6, 0.42, 0.5, 0.44, 0.48, 0.58, 0.48, 0.64, 0.58, 0.4, 0.44, 0.46, 0.58, 0.6, 0.52, 0.5, 0.48, 0.54, 0.48, 0.62, 0.56, 0.48, 0.36, 0.56, 0.42, 0.52, 0.38 ...

# %%
plt.hist(sample_means, bins=54)
plt.show()

# %% [markdown]
# What does the Central Limit Theorem State? That no matter the initial distribution of the population, the distribution of sample means taken will approximate a normal distribution as $n \rightarrow \infty$.
#
# This has very important implications for hypothesis testing and is precisely the reason why the t-distribution begins to approximate the normal distribution as our sample size increases.

# %%
sample_means_small = []
sample_means_large = []
for x in range(0,3000):
  coinflips_small = np.random.binomial(n=1, p=.5, size=50)
  coinflips_large = np.random.binomial(n=1, p=.5, size=200)
  one_small_sample = coinflips_small
  one_small_large = coinflips_large
  sample_means_small.append(coinflips_small.mean())
  sample_means_large.append(coinflips_large.mean())

print(len(sample_means_small))
print(sample_means_small)
# Out:
# 3000
# [0.54, 0.42, 0.54, 0.46, 0.46, 0.58, 0.58, 0.56, 0.52, 0.56, 0.42, 0.54, 0.58, 0.46, 0.38, 0.48, 0.38, 0.5, 0.48, 0.44, 0.56, 0.48, 0.6, 0.6, 0.36, 0.5, 0.56, 0.54, 0.4, 0.56, 0.5, 0.56, 0.52, 0.4, 0.5, 0.56, 0.52, 0.48, 0.48, 0.5, 0.62, 0.48, 0.44, 0.48, 0.62, 0.52, 0.52, 0.54, 0.34, 0.48, 0.52, 0.42, 0.52, 0.42, 0.52, 0.56, 0.5, 0.56, 0.54, 0.5, 0.52, 0.54, 0.56, 0.56, 0.46, 0.48, 0.5, 0.54, 0.66, 0.46, 0.42, 0.52, 0.6, 0.46, 0.4, 0.54, 0.46, 0.58, 0.4, 0.54, 0.4, 0.5, 0.52, 0.46, 0.5, 0.46, 0.44, 0.5, 0.52, 0.56, 0.52, 0.5, 0.52, 0.42, 0.58, 0.6, 0.58, 0.6, 0.66, 0.42, 0.6, 0.56, 0.56, 0.48, 0.44, 0.56, 0.5, 0.54, 0.42, 0.44, 0.5, 0.42, 0.52, 0.58, 0.44, 0.62, 0.38, 0.48, 0.36, 0.42, 0.48, 0.42, 0.52, 0.48, 0.56, 0.52, 0.58, 0.48, 0.46, 0.54, 0.58, 0.5, 0.5, 0.42, 0.52, 0.48, 0.48, 0.58, 0.5, 0.36, 0.34, 0.52, 0.46, 0.6, 0.56, 0.44, 0.52, 0.64, 0.56, 0.5, 0.44, 0.46, 0.4, 0.5, 0.52, 0.48, 0.5, 0.32, 0.46, 0.62, 0.48, 0.48, 0.52, 0.48, 0.5, 0.58, 0.58, 0.4, 0.48, 0.46, 0.5, 0.48, 0.52, 0.62, 0.46, 0.52, 0.56, 0.42, 0.54, 0.48, 0.58, 0.44, 0.44, 0.46, 0.5, 0.52, 0.42, 0.58, 0.48, 0.4, 0.52, 0.44, 0.5, 0.48, 0.46, 0.44, 0.5, 0.54, 0.46, 0.58, 0.58, 0.6, 0.48, 0.46, 0.4, 0.58, 0.5, 0.46, 0.52, 0.42, 0.46, 0.4, 0.44, 0.46, 0.5, 0.48, 0.52, 0.52, 0.44, 0.44, 0.44, 0.46, 0.52, 0.46, 0.48, 0.5, 0.42, 0.52, 0.58, 0.54, 0.52, 0.48, 0.56, 0.38, 0.52, 0.6, 0.42, 0.6, 0.48, 0.5, 0.38, 0.44, 0.5, 0.36, 0.46, 0.54, 0.38, 0.48, 0.5, 0.48, 0.4, 0.44, 0.52, 0.56, 0.48, 0.46, 0.58, 0.36, 0.54, 0.6, 0.42, 0.5, 0.5, 0.44, 0.44, 0.54, 0.58, 0.46, 0.46, 0.34, 0.44, 0.32, 0.5, 0.52, 0.46, 0.52, 0.44, 0.42, 0.58, 0.42, 0.52, 0.46, 0.5, 0.4, 0.56, 0.48, 0.52, 0.7, 0.62, 0.58, 0.44, 0.54, 0.58, 0.6, 0.44, 0.64, 0.54, 0.48, 0.46, 0.46, 0.62, 0.62, 0.48, 0.48, 0.54, 0.48, 0.44, 0.62, 0.42, 0.46, 0.48, 0.44, 0.52, 0.42, 0.5, 0.54, 0.42, 0.58, 0.6, 0.48, 0.46, 0.44, 0.44, 0.5, 0.48, 0.46, 0.5, 0.52, 0.52, 0.64, 0.56, 0.58, 0.62, 0.52, 0.62, 0.38, 0.52, 0.4, 0.58, 0.6, 0.54, 0.48, 0.5, 0.52, 0.5, 0.54, 0.4, 0.56, 0.46, 0.4, 0.52, 0.5, 0.54, 0.42, 0.42, 0.42, 0.44, 0.58, 0.4, 0.54, 0.46, 0.36, 0.54, 0.48, 0.7, 0.46, 0.52, 0.46, 0.5, 0.4, 0.66, 0.42, 0.58, 0.5, 0.46, 0.68, 0.4, 0.5, 0.42, 0.5, 0.56, 0.36, 0.44, 0.48, 0.52, 0.42, 0.58, 0.34, 0.36, 0.64, 0.54, 0.38, 0.46, 0.46, 0.42, 0.58, 0.42, 0.5, 0.52, 0.54, 0.5, 0.44, 0.54, 0.42, 0.54, 0.64, 0.5, 0.48, 0.42, 0.6, 0.48, 0.42, 0.5, 0.46, 0.5, 0.34, 0.54, 0.58, 0.58, 0.58, 0.56, 0.6, 0.48, 0.36, 0.58, 0.56, 0.52, 0.48, 0.34, 0.46, 0.5, 0.6, 0.56, 0.42, 0.42, 0.28, 0.64, 0.56, 0.58, 0.4, 0.62, 0.5, 0.42, 0.52, 0.6, 0.5, 0.46, 0.48, 0.5, 0.4, 0.5, 0.56, 0.6, 0.54, 0.48, 0.46, 0.54, 0.46, 0.46, 0.62, 0.52, 0.58, 0.46, 0.48, 0.42, 0.5, 0.56, 0.58, 0.5, 0.5, 0.38, 0.56, 0.56, 0.52, 0.46, 0.52, 0.52, 0.4, 0.42, 0.46, 0.42, 0.5, 0.5, 0.5, 0.58, 0.52, 0.62, 0.4, 0.5, 0.5, 0.54, 0.4, 0.56, 0.58, 0.48, 0.38, 0.68, 0.48, 0.62, 0.5, 0.52, 0.44, 0.4, 0.52, 0.52, 0.54, 0.72, 0.64, 0.54, 0.62, 0.46, 0.76, 0.4, 0.44, 0.62, 0.48, 0.62, 0.54, 0.5, 0.52, 0.52, 0.5, 0.58, 0.5, 0.56, 0.48, 0.54, 0.5, 0.54, 0.48, 0.56, 0.5, 0.48, 0.48, 0.5, 0.54, 0.4, 0.42, 0.46, 0.58, 0.46, 0.44, 0.56, 0.46, 0.48, 0.48, 0.46, 0.66, 0.48, 0.54, 0.48, 0.44, 0.56, 0.5, 0.48, 0.54, 0.5, 0.52, 0.58, 0.62, 0.46, 0.58, 0.46, 0.52, 0.54, 0.46, 0.56, 0.4, 0.48, 0.46, 0.44, 0.46, 0.5, 0.54, 0.46, 0.46, 0.48, 0.48, 0.48, 0.46, 0.52, 0.56, 0.5, 0.5, 0.54, 0.46, 0.4, 0.5, 0.42, 0.52, 0.56, 0.56, 0.48, 0.46, 0.32, 0.36, 0.54, 0.46, 0.48, 0.46, 0.52, 0.52, 0.52, 0.56, 0.5, 0.54, 0.46, 0.52, 0.38, 0.56, 0.5, 0.54, 0.5, 0.48, 0.5, 0.38, 0.64, 0.62, 0.58, 0.48, 0.54, 0.36, 0.46, 0.58, 0.46, 0.66, 0.56, 0.66, 0.52, 0.5, 0.56, 0.42, 0.56, 0.7, 0.48, 0.46, 0.64, 0.54, 0.52, 0.42, 0.5, 0.52, 0.42, 0.42, 0.58, 0.58, 0.56, 0.4, 0.52, 0.46, 0.46, 0.58, 0.54, 0.44, 0.54, 0.54, 0.5, 0.62, 0.52, 0.6, 0.62, 0.54, 0.52, 0.5, 0.5, 0.52, 0.5, 0.46, 0.44, 0.6, 0.44, 0.52, 0.44, 0.48, 0.46, 0.58, 0.58, 0.48, 0.56, 0.56, 0.4, 0.58, 0.48, 0.52, 0.38, 0.4, 0.48, 0.58, 0.54, 0.44,  ...

# %%
import seaborn as sns

fig, ax = plt.subplots()
for sample in [sample_means_small, sample_means_large]:
  sns.distplot(sample)

# %% [markdown]
# ## Standard Error of the Mean
#
# SE of the mean is... the standard deviation of this imaginary distribution of sample means (like the ones we're creating above)
#
# \begin{align}
# SE_{\bar{X}} = \frac{s}{\sqrt{n}}
# \end{align}

# %% [markdown]
# ## Build and Interpret a Confidence Interval
#
# <img src="https://github.com/ryanallredblog/ryanallredblog.github.io/blob/master/img/Confidence_Interval.png?raw=true" width=400>

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ryanleeallred/datasets/master/adult.csv', na_values=' ?')

print(df.shape)
df.head(15)
# Out:
# (32561, 15)
#     age          workclass  fnlwgt  ... hours-per-week         country  salary
# 0    39          State-gov   77516  ...             40   United-States   <=50K
# 1    50   Self-emp-not-inc   83311  ...             13   United-States   <=50K
# 2    38            Private  215646  ...             40   United-States   <=50K
# 3    53            Private  234721  ...             40   United-States   <=50K
# 4    28            Private  338409  ...             40            Cuba   <=50K
# 5    37            Private  284582  ...             40   United-States   <=50K
# 6    49            Private  160187  ...             16         Jamaica   <=50K
# 7    52   Self-emp-not-inc  209642  ...             45   United-States    >50K
# 8    31            Private   45781  ...             50   United-States    >50K
# 9    42            Private  159449  ...             40   United-States    >50K
# 10   37            Private  280464  ...             80   United-States    >50K
# 11   30          State-gov  141297  ...             40           India    >50K
# 12   23            Private  122272  ...             30   United-States   <=50K
# 13   32            Private  205019  ...             50   United-States   <=50K
# 14   40            Private  121772  ...             40             NaN    >50K
#
# [15 rows x 15 columns]

# %% [markdown]
# ## What is the average age of Census Responders?

# %% [markdown]
# <img src="https://github.com/ryanallredblog/ryanallredblog.github.io/blob/master/img/Confidence_Interval.png?raw=true" width=400>
#
# $\bar{x}$ = our sample mean
#
# s = sample standard deviation
#
# n = sample size
#
# t =  The t-statistic that captures 95% of the area under the t-statistic curve for whichever t-distribution we're working with.
#
# The t-distribution that we're working with is determined by our degrees of freedom.

# %%
sample1 = df.sample(20, random_state=20)

sample2 = df.sample(200, random_state=20)

# %%
sample1['age'].mean()
# Out:
# 38.35

# %%
sample2['age'].mean()
# Out:
# 39.045

# %% [markdown]
# ### NumPy by DEFAULT calculates the POPULATION standard deviation and NOT the SAMPLE standard deviation
#
# We need to pass the parameter `ddof=1` in order to ensure that we're really calculating the sample standard deviation and not the population standard deviation

# %%
from scipy import stats

def confidence_interval(data, confidence=.95):
  # Make sure we're working with a numpy array
  sample = np.array(data)
  # Sample Mean
  x_bar = sample.mean()
  # Sample Standard Deviation
  s = np.std(sample, ddof=1)
  # Sample Size
  n = len(sample)
  # T statistic - correspond to our confidence level, and our degrees of freedom
  t = stats.t.ppf((1+confidence) / 2, n-1)
  # Standard Error
  std_err = s / np.sqrt(n)
  # Margin of Error
  moe = std_err * t
  # Lower and Upper Bound
  upper = x_bar + moe
  lower = x_bar - moe

  return (lower, x_bar, upper)

confidence_interval(sample1['age'])
# Out:
# (32.33484327830995, 38.35, 44.365156721690056)

# %%
def confidence_interval(data, confidence=.95):
  # Make sure we're working with a numpy array
  sample = pd.Series(data)
  # Sample Mean
  x_bar = sample.mean()
  # Sample Standard Deviation
  s = sample.std()
  # Sample Size
  n = len(sample)
  # T statistic - correspond to our confidence level, and our degrees of freedom
  t = stats.t.ppf((1+confidence) / 2, n-1)
  # Standard Error
  std_err = s / np.sqrt(n)
  # Margin of Error
  moe = std_err * t
  # Lower and Upper Bound
  upper = x_bar + moe
  lower = x_bar - moe

  return (lower, x_bar, upper)

confidence_interval(sample1['age'])
# Out:
# (32.33484327830995, 38.35, 44.365156721690056)

# %%
confidence = .95

(1+confidence) / 2
# Out:
# 0.975

# %%
confidence = .99

(1+confidence) / 2
# Out:
# 0.995

# %%
confidence = .5

(1+confidence) / 2
# Out:
# 0.75

# %% [markdown]
# ## Different Techniques for Communicating a Confidence Interval
#
# 1) Report the lower bound, mean, and upper bounds

# %%
# Confidence Interval with sample size of 20
CI1 = confidence_interval(sample1['age'])
CI1
# Out:
# (32.33484327830995, 38.35, 44.365156721690056)

# %%
# Confidence Interval with sample size of 200
CI2 = confidence_interval(sample2['age'])
CI2
# Out:
# (37.17135197896141, 39.045, 40.91864802103859)

# %% [markdown]
# 2) Report the Mean and the Margin of Error

# %%
print("Census Responder Age Estimate 1")
print("Mean:", CI1[1])
print("MOE:", CI1[2]-CI1[1])
# Out:
# Census Responder Age Estimate 1
# Mean: 38.35
# MOE: 6.0151567216900546

# %%
print("Census Responder Age Estimate 1")
print("Mean:", CI2[1])
print("MOE:", CI2[2]-CI2[1])
# Out:
# Census Responder Age Estimate 1
# Mean: 39.045
# MOE: 1.8736480210385906

# %% [markdown]
# ## Graphically Represent a Confidence Interval

# %%
# Density Plot and overlay our Confidence Interval Bounds
# Confidence Interval *DOES NOT* capture 95% of the raw data
# it captures 95% of potential sample means

sample1['age'].plot.density()
plt.axvline(CI1[0], color='black')
plt.axvline(CI1[1], color='red')
plt.axvline(CI1[2], color='black')
plt.title('95% confidence interval for \n average age of Census responders')
plt.show()

# %%
sample1['age'].plot.density()
plt.axvline(CI2[0], color='black')
plt.axvline(CI2[1], color='red')
plt.axvline(CI2[2], color='black')
plt.title('95% confidence interval for \n average age of Census responders')
plt.show()

# %%
# plt.errorbar
plt.errorbar(x=0, y=CI1[1], yerr=(CI1[2]-CI1[1]), fmt='o')
plt.errorbar(x=1, y=CI2[1], yerr=(CI2[2]-CI2[1]), fmt='o')
plt.title('95% confidence intervals for \n average age of Census responders')
plt.xticks(ticks=[0,1], labels=['sample 1', 'sample 2'])
plt.xlim(-.5, 1.5)
plt.show()

# %%
# plt.errorbar
plt.bar(x=0, height=CI1[1], yerr=(CI1[2]-CI1[1]))
plt.bar(x=1, height=CI2[1], yerr=(CI2[2]-CI2[1]))
plt.title('95% confidence intervals for \n average age of Census responders')
plt.xticks(ticks=[0,1], labels=['sample 1', 'sample 2'])
plt.xlim(-.5, 1.5)
plt.show()

# %% [markdown]
# ### use scipy to calculate standard error:

# %%
stats.sem(sample1['age'])
# Out:
# 2.873907114933111

# %%
stats.sem(sample2['age'])
# Out:
# 0.9501467091161349

# %% [markdown]
# ### stats.bayes_mvs() can be used to calculate confidence intervals
#
# Careful: default confidence level is 90%

# %%
stats.bayes_mvs(sample1['age'], alpha=.95)
# Out:
# (Mean(statistic=38.35, minmax=(32.33484327830995, 44.365156721690056)),
#  Variance(statistic=184.6205882352941, minmax=(95.53508989514398, 352.38805276420055)),
#  Std_dev(statistic=13.389274634727967, minmax=(9.774205333178957, 18.77200183156289)))

# %%
confidence_interval(sample1['age'])
# Out:
# (32.33484327830995, 38.35, 44.365156721690056)

# %% [markdown]
# ## Relationship between Confidence Intervals and T-tests
#
# ### (Bonus Content) You will not be assessed on this material
#
# Confidence Interval == Bounds of statistical significance for our t-test
#
# A sample mean that falls inside of our confidence interval will "FAIL TO REJECT" our null hypothesis
#
# A sample mean that falls outside of our confidence interval will "REJECT" our null hypothesis

# %%
confidence_interval(sample1['age'])
# Out:
# (32.33484327830995, 38.35, 44.365156721690056)

# %% [markdown]
# ### Upper Bound

# %%
# inside the confidence interval
stats.ttest_1samp(sample1['age'], 44.36515)
# Out:
# Ttest_1sampResult(statistic=-2.09302171554003, pvalue=0.05000023130586654)

# %%
# outside the confidence interval
stats.ttest_1samp(sample1['age'], 44.36516)
# Out:
# Ttest_1sampResult(statistic=-2.0930251951236087, pvalue=0.04999988718761072)

# %% [markdown]
# ### Lower Bound

# %%
# inside the confidence interval
stats.ttest_1samp(sample1['age'], 32.33485)
# Out:
# Ttest_1sampResult(statistic=2.09302171554003, pvalue=0.05000023130586654)

# %%
# outside the confidence interval
stats.ttest_1samp(sample1['age'], 32.33483)
# Out:
# Ttest_1sampResult(statistic=2.093028674707187, pvalue=0.04999954307149878)

# %% [markdown]
# If a null hypothesis value falls outside of our confidence interval, we will reject the null hypothesis.
#
# If a null hypothesis value falls inside of our confidence interval we will fail to reject the null hypothesis.

# %% [markdown]
# A null hypothesis that's just inside of our confidence interval == fail to reject

# %% [markdown]
# A null hypothesis that's just outside of our confidence interval == reject

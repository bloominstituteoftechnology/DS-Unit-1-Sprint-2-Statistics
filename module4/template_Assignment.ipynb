# %% [markdown]
# <a href="https://colab.research.google.com/github/rselent/DS-Unit-1-Sprint-2-Statistics/blob/master/module4/template_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment!
#
# Fill out the template *twice*, for two different ideas.
#
# Then compare and contrast and select one as the idea you're leaning towards
# working on for your project week.
#
#
# # Ideas for data storytelling - Idea 1
#
# ## You
#
# What do you care about?
#
# *   A lot of things, actually. Social issues, politics, animal welfare, the environment, science and scientific breakthroughs in almost all disciplines, and more
#
# What do you know about?
#
# *   A lot of things, again. Soccer, cars, politics, journalism, tech, video games, global news, science, space, our lord and saviour Cthulhu
#
# What decisions do you face?
#
# *   A lot? lol
#
#     But really, I guess it depends on what your (my?) definition of a 'decision' is, because it could be argued that even the smallest action -- say, typing on a keyboard -- is in fact a decision; each keystroke is its own individual result of traveling down that decision tree. That said, that is *exceptionally* pedantic and probably unhelpful to all but the most ardent of philosophers...
#
#     So, after thinking through all of that, frankly, bs, I've come to the conclusion that my first Topic would be **How The Differences Between Nationalized and Privatized Healthcare Affect Life Expectancy**
#
# ## Seven templates
#
# Training Kit (https://learn.lambdaschool.com/ds/module/recedjanlbpqxic2r) explains the seven templates from Priceonomics.
#
# Can you apply the templates to your topics?
#
# 1. Geographic Variation
#
#     *   Either:
#         *   Differences between the US and EU countries, or
#         *   Differences between US states' implementations of the Affordable Care Act
#
# 2. Trend related to the news
#
#     *   Most Democratic primary candidates have some sort of Nationalized healthcare plan -- which style of implementation could be best?
#
# 3. Who does that?
#
#     *   Everyone?
#
# 4. Answering a question people care about
#
#     *   The actual, real dollar cost of Nationalized healthcare vis-a-vis privatized, per person per capita (Not "*OH NO IT'S GOING TO COST $40 BAJILLION OVER THE NEXT 12.37 YEARS*")
#
# 5. Valuable to businesses
#
#     *   Nationalized healthcare, even if at the surface it might cost more money through generalized taxation for businesses, it could possibly save *even more* as businesses no longer have to provide that benefit to employees, nor the overhead to administer or support it
#
# 6. What's the most popular?
#
#     *   Quite broadly, just compare the number of First World countries that have a Nationalized healthcare system vs those that are privatized -- that's popularity right there
#
# 7. Cost/Money rankings
#
#     *   Alluded to before: the actual, real dollar cost per person per capita of a Nationalized system vs what it is now, privatized
#
# ## Misconceptions
#
# What misconceptions do people have about your topic?
#
# *   That "socialism" and social programs like Nationalized healthcare are the antithesis of concepts like "freedom" and "capitalism" and all the "happiness" that they create.
#
# ## Examples
#
# What data storytelling example inspires you?
#
#
# Could you do a new hypothesis, for the same question?
#
#
# Could you do a new question, for the same topic?
#
#
# Could you do a new topic, with the same "style"?
#
#
# ## Data
#
# Where could you search for data about your topic?
#
# the World Health Organization / UN database,
#
# Nat'l Institute of Health,
#
# Fourth Estate organizations like the Washington Post or the New York Times probably have a lot of data as well or could at least point me towards more primary sources (just like wikipedia)
#
# EU Open Data Portal
#
# ---
#
# # Ideas for data storytelling - Idea 2
#
# ## You
#
# What do you care about?
#
# *   Asking better questions
#
# What do you know about?
#
# *   I know that these three questions don't really help me hone in on an effective topic or question, but that's ok
#
# What decisions do you face?
#
# *   So instead, my decision process needs (tends?) to look more like "something interesting in the world >> do people generally hold any sort of misconception about this? >> let's explore that"
#
#     That said, a second idea I had revolved around -- and I know it's a bit of a hot-button issue, but hear me out -- *Pokemon GO*. I would like to explore how it's not *just a game*; how data like the rarity of certain pokemon can potentially be a benefit for a player's health (via walking and being outside), particularly if they want to collect (compulsively or not) those rarer pokemon.
#
#     It doesn't feel as strong as my first idea, admittedly -- although it definitely feels *easier* -- but not everything's a winner ¯\\\_(ツ)_/¯
#
#     Admittedly, I also don't feel that strongly about this idea, either. It just feels like an entertaining alternative to the first idea here, which, in comparison is a lot more serious and **a lot** more work -- I'm not opposed to doing a lot of work, but perhaps I shouldn't jump into writing a 25-page thesis for my first project at Lambda
#
# ## Seven templates
#
# Training Kit (https://learn.lambdaschool.com/ds/module/recedjanlbpqxic2r) explains the seven templates from Priceonomics.
#
# Can you apply the templates to your topics?
#
# 1. Geographic Variation
#
#     *   Presumably, the app would be more/less used in different cities depending on how pedestrian-friendly each city is, but I feel like this might be outside the scope of my question/topic
#
# 2. Trend related to the news
#
#     *   N/A
#
# 3. Who does that?
#
#     *   Smartphone users, probably users under 40 (people who grew up with Pokemon), but also outside scope
#
# 4. Answering a question people care about
#
#     *   Perhaps how rare a Pikachu or Charizard really is? I wouldn't say it's a question that people *really care about*, but it still has the potential to be fun at parties ¯\\\_(ツ)_/¯
#
# 5. Valuable to businesses
#
#     *   Outside of Niantic (the developer) or Nintendo (trademark owner), this is limited. Maybe advertisers might be interested? Billboard owners, like ClearChannel Communications? ¯\\\_(ツ)_/¯
#
# 6. What's the most popular?
#
#     *   Relating it to my topic, this could probably be the pokemon with the highest drop rate, or the most common ones, but then -- if the metric is available -- compare that to the most **desired**. Both are popular, but for different reasons
#
# 7. Cost/Money rankings
#
#     *   Pokemon GO does have an in-game store in which they sell items that could aid in catching pokemon, lowering the difficulty even. Perhaps there's some data there (even if it has to be extrapolated), regarding how much it could potentially cost to catch the most desired or most rare pokemon
#
# ## Misconceptions
#
# What misconceptions do people have about your topic?
#
# *   "*It's just a gaaaaaame, it's not good for anything*"
#
#
#
# ## Examples
#
# What data storytelling example inspires you?
#
#
# Could you do a new hypothesis, for the same question?
#
#
# Could you do a new question, for the same topic?
#
#
# Could you do a new topic, with the same "style"?
#
#
# ## Data
#
# Where could you search for data about your topic?
#
# *   Initial, cursory research turned up only one community-sourced dataset (on data.world) that has the data I need, namely rarity percentages

# %% [markdown]
# # Bayesian Inference
#
# ## Objectives:
#
# - **Use conditional probabilities** and understand the **mathematical notation** associated with them
# - Compare and contrast **frequentist** and **Bayesian** approaches to inference
# - **Use Bayes' Theorem** to iteratively update a prior probability

# %% [markdown]
# ## Why Learn Bayesian Inference?
#
# - Naive Bayes Classifiers (ML)
# - Bayesian Hyperparameter Tuning (For Neural Nets + Complex ML)
# - Optimization
# - Lots of other cool machine learning stuff
#
# *These are examples of topics we will be covering later in the course.*

# %% [markdown]
# ## Conditional Probability
#
# Remember back in Module 1 when I said there are lots and lots (and lots and lots and lots) of rules of probability.  We're going to talk about one more now.

# %% [markdown]
# ### The Law of Conditional Probability
#
# Let A and B be two events.  The probability of A given B is equal to the probability of A and B divided by the probability of B.
#
# The formula for actual calculation:
#
# $$P(A|B) = \frac{P(A \cap B)}{P(B)}$$

# %% [markdown]
# Let's see this in action as we try to predict the probability of survival for a passenger on the Titanic.

# %%
import pandas as pd
import numpy as np


data_url = 'https://raw.githubusercontent.com/Chelsea-Myers/Lambda-Intro/master/Titanic.csv'

df = pd.read_csv(data_url, skipinitialspace=True, header=0)

print(df.shape)
df.head()

# %% [markdown]
# Let A be the event of surviving the sinking and B be the event of being a male passenger.
#
# $$P(A|B) = \frac{P(A \cap B)}{P(B)}$$
#
# P(A|B) = the probability of _______ given that the passenger was ________
#
# P(A $\cap$ B) = the probability of _________ and _________
#
# P(B) = the probability of ___________

# %% [markdown]
# We can actually calculate all of those quantities from our data and show that they are equal.

# %%
#Crosstab of Sex and Survived
pd.crosstab(df['Sex'],df['Survived'],margins=True)
# Out:
# Survived    0    1  All
# Sex
# female     81  233  314
# male      464  109  573
# All       545  342  887

# %%
#P_B
P_B = 
print(P_B)


#Calculate P_A_and_B
P_A_and_B = 
print(P_A_and_B)

# %% [markdown]
# By the Law of Large Numbers,
#
# P(B) = P(Male) =
#
# P(A and B) = P(Survived and Male) =

# %% [markdown]
# Let A be the event of surviving the sinking and B be the event of being a male passenger.
#
# $$P(A|B) = \frac{???}{????}$$

# %%
P_A_given_B = P_A_and_B/P_B 

print(P_A_given_B)

# %% [markdown]
# Using Bayes Rule, we calculate the P(A|B) = _________

# %% [markdown]
# Now let's check to see if this matches what we get when we calculate the conditional probability of surviving given that a passenger is male.

# %%
pd.crosstab(df['Sex'],df['Survived'],normalize="index")

# %% [markdown]
# P(A|B) = P(Survived|Male) = __________

# %% [markdown]
# It works!

# %% [markdown]
# #Who was Bayes and why do we care about Bayesian statistics?

# %% [markdown]
# Thomas Bayes (c. 1701 – 7 April 1761)was an English statistician, philosopher and Presbyterian minister who is known for formulating a specific case of the theorem that bears his name: Bayes' theorem.

# %% [markdown]
# Bayes never published what would become his most famous accomplishment; his notes were edited and published after his death by Richard Price.
#
# This has led to some speculation as to whether Bayes actually thought his rule was a good idea or not!
#
# Credit also belongs two another mathematician, Pierre-Simpon Laplace (inventor of the Central Limit Theorem) who deveoped Bayes' rule in its modern form.

# %% [markdown]
# ###Bayes was working on a specific problem that perplexed mathematicians and staticticans of his day (who - by the way - were pretty much all compulsive gamblers).
#
# In the first decades of the eighteenth century, many problems concerning the probability of certain events, given specified conditions, were solved. For example: given a specified number of white and black balls in an urn, what is the probability of drawing a black ball?
#
# > This should sound like conditional probability (ie P(A|B)) above.
#
# It was also pretty simple to figure out the probability of a single event (ie. P(B) ).
#
# However, P(A $\cap$ B) often remained unknown.
#
# By figuring out
#
# $P(A|B) = \frac{P(A \cap B)}{P(B)}$
#
# Bayes Rule allows us to solve
#
# P(A $\cap$ B) = P(A|B) x P(B)

# %% [markdown]
# ###So... what?

# %% [markdown]
# The Big Idea that came out of this was the scientific framework:
#
# **________**
#
# Bayes' Rule was important in
#
#
# *   Cracking the code of the German Enigma Machine (Alan Turing)
# *   The development of the "bit" (Claude Shannon)
# * [And many, many other applications](https://www.lesswrong.com/posts/RTt59BtFLqQbsSiqd/a-history-of-bayes-theorem)

# %% [markdown]
# ## Bayesian vs Frequentist Inference

# %% [markdown]
# ![frequentists_vs_bayesians_2x.png](data:image/png;base64,...)

# %% [markdown]
# The joke explained: https://www.explainxkcd.com/wiki/index.php/1132:_Frequentists_vs._Bayesians

# %% [markdown]
# ###What really is the difference between the Bayesian and frequentist approach?

# %% [markdown]
# ![1-A-brief-comparison-of-frequentist-and-Bayesian-statistics.png](data:image/png;base64,...)

# %% [markdown]
# #### If we wanted to know the true mean height of all male emperor penguins:
# > **Frequentist**: “We humans don't know the true mean height of all male emperor penguins; however, there is exactly one true mean height that could be knowable to - say - an advanced alien species."
#
# > **Bayesian**: “Hang on, that's crazy!  Emperor penguins are born and die every second.  How could there possibly be one single answer to that question?  There will always be uncertainty around the true value of the population mean.”
#
# > **Bayesian also**: “And by the way, we already know something about how tall emperor penguins are.  We know they aren't 4 inches tall and we know they aren't 40 feet tall.  Shouldn't we incorporate this prior knowledge into our estimate in some way?”

# %% [markdown]
# #Bayesian Statistical Modeling in Action

# %% [markdown]
# ## Let's get even more fancy with Bayes' Rule
#
# Start with:
#
# $P(A|B) = \frac{P(A \cap B)}{P(B)}$
#
# But wait!
#
# P(A $\cap$ B) = P(B $\cap$ A)
#
# So!
#
# We can re-write
#
# P(B $\cap$ A) = P(B|A) x P(A)
#
# And substitute into our orignal formula to get
#
# $P(A|B) = \frac{P(B|A)P(A)}{P(B)}$
#
# ###Woah...

# %% [markdown]
# All of these terms have important functions in calculating the probability of an outcome using a Bayesian framework.

# %% [markdown]
# ![featured.png](data:image/png;base64,...)

# %% [markdown]
# * The **___________** probability is the probability of the event of interest happening.
#
# * The **_____________** is what we could consider normal hypothesis testing if we were frequentists.
#
# * The **_____________** is our prior knowledge about the outcome
#
# * The **______________** is evidence from a sample or experiment

# %% [markdown]
# Another way to think about this is:
#
# P(hypothesis|data) = P(data|hypothesis)P(hypothesis)/P(data)

# %% [markdown]
# The cool thing about Bayesian statistics is that we don't do this just once.  It's an _____________________ where we calculate a posterior probability, plug *that* value in for the prior probability, calculate another posterior probability, plug that in for prior probability, and on and on.

# %% [markdown]
# We stop the interative process when the posterior probability stops changing with repeated iterations.  We say that our algorithm has ______________ on the answer.

# %% [markdown]
# #Comparing a 95% confidence interval (frequentist) to a Bayesian confidence interval
#
# Assume that the passengers on the Titanic are representative of all individuals traveling from Western Europe to the United States in the early 20th century.
#
# Let's use the Titanic data sample to estimate the mean age of all individuals traveling from Western Euorpe to the United States during that time.

# %%
#Using a t-interval:

from scipy.stats import t

#Calculate the mean and SE of age

mean_age = df['Age'].mean()


sd_age = df['Age'].std() 
n_age = df['Age'].count()

se_age = sd_age / (n_age**(1/2))


t.interval(alpha= 0.95, df=n_age - 1, loc=mean_age, scale=se_age)
# Out:
# (28.540820985809045, 30.40206514722365)

# %% [markdown]
# We are 95% confident that the true mean age of all travelers from Western Europe to the US during the early 20th century was between 28.5 and 30.4 years old.

# %%
#Using Bayesian MVS (Mean, variance, standard deviation)

from scipy import stats

stats.bayes_mvs(df['Age'], alpha=0.95)
# Out:
# (Mean(statistic=29.471443066516347, minmax=(28.54082098580904, 30.402065147223652)),
#  Variance(statistic=199.87949225438336, minmax=(182.08639591956043, 219.38451490457692)),
#  Std_dev(statistic=14.1338766880582, minmax=(13.493939229133959, 14.81163444406379)))

# %% [markdown]
# We are 95% confident that the true mean age of all travelers from Western Europe can be described by a statistical distribution that has a mean of 29.5 years and a standard deviation of 14.13 years.

# %% [markdown]
# What difference do we notice between the two estimates?
#
#
# *   A notion of undertainty surrounding not only the population parameter but also the values of variance and standard deviation (variance = SD^2)

# %% [markdown]
# Wait...?  I thought we were supposed to include prior information in our model.  I didn't include any prior information.  Where's that coming from?
#
#
# Python is ________________
#
#
# The cool/ weird/ counterintuitive thing about this Bayesian framework is that it actually doesn't matter what you specify as your prior information when you start.  Over time, your model will get updated over and over again until you converge on the right answer.
#
# Better priors = ______________, but a bad prior will get you there eventually.

# %% [markdown]
# ###In the future, you'll actually talk about how to calculate probabilities using a Bayesian framework.
#
# For example: Using a Bayesian famework, what is the probability that the mean age of individuals on a ship from Western Europe bound for the US during the early 20th century is older than 35 years?
